# %%
from zipfile import ZipFile

# Use a method to attempt to extract the zip file with a given password
def attempt_extract(zf_handle, password):
    try:
        zf_handle.extractall(pwd=password.encode())
        print(f"Successfully extracted with password: {password}")
        return True
    except RuntimeError:
        print(f"Failed to extract with password: {password}")
        return False

def main():
    print("[+] Beginning bruteforce ")
    with ZipFile('enc.zip') as zf:
        with open('rockyou.txt', 'r') as f:
            passwords = f.readlines()
            passwords = [password.strip() for password in passwords]
            for password in passwords:
                if attempt_extract(zf, password):
                    break
            else:
                print("Extraction failed. No correct password found.")

if __name__ == "__main__":
    main()
# Out:
# [+] Beginning bruteforce
# Failed to extract with password: 123456
# Failed to extract with password: 12345
# Failed to extract with password: 123456789
# Failed to extract with password: password
# Failed to extract with password: 1234567
# Failed to extract with password: rockyou
# Failed to extract with password: 12345678
# Failed to extract with password: abc123
# Failed to extract with password: nicole
# Failed to extract with password: daniel
# Failed to extract with password: monkey
# Failed to extract with password: lovely
# Failed to extract with password: jessica
# Failed to extract with password: 654321
# Failed to extract with password: michael
# Failed to extract with password: ashley
# Failed to extract with password: qwerty
# Failed to extract with password: 111111
# Failed to extract with password: iloveu
# Failed to extract with password: 000000
# Failed to extract with password: michelle
# Failed to extract with password: volleyball
# ...

# %%
'''import zipfile

def extract_zip_with_password(zip_file_path, password_file_path):
    with open(password_file_path, 'r') as password_file:
        passwords = password_file.readlines()
        passwords = [password.strip() for password in passwords]

    with zipfile.ZipFile(zip_file_path) as zip_file:
        for password in passwords:
            try:
                zip_file.extractall(pwd=password.encode())
                print(f"Successfully extracted with password: {password}")
                break
            except RuntimeError:
                print(f"Failed to extract with password: {password}")
        else:
            print("Extraction failed. No correct password found.")


zip_file_path = 'example.zip'
password_file_path = 'passwords.txt'
extract_zip_with_password(zip_file_path, password_file_path)
'''
# Out:
# "'# Example usage:\nzip_file_path = 'example.zip'\npassword_file_path = 'passwords.txt'\nextract_zip_with_password(zip_file_path, password_file_path)\n"
